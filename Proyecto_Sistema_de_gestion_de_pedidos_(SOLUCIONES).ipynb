# %% [markdown]
# # Proyecto aplicado: Gestión simple de pedidos
#
# ### Práctica de listas, tuplas y diccionarios en Python

# %% [markdown]
# Este ejercicio práctico está asociado al curso disponible en LINK

# %% [markdown]
# ## Parte 1 : Información del producto (tuplas)
# --> La información de un producto no debe cambiar.

# %% [markdown]
# **Instrucción**
#
# Cada producto se representa con una tupla que contiene:
# - nombre del producto
# - precio

# %%
# Tuplas de productos (NO MODIFICAR)
product_1 = ("Laptop", 1200)
product_2 = ("Mouse", 25)
product_3 = ("Keyboard", 80)

# %% [markdown]
# **Pregunta (responde en un comentario)**

# %%
# ¿Por qué una tupla es una buena opción para guardar los datos de un producto?

# Porque los datos de un producto no deben cambiar. Una tupla es inmutable,
# lo que nos ayuda a mantener la información fija y evitar modificaciones por error.

# %% [markdown]
# ## Parte 2 : Productos del pedido (Lista)

# %% [markdown]
# **Instrucción**
#
# Crea una lista con los productos del pedido.

# %%
# TODO: crea una lista llamada order_products
# Debe contener product_1 y product_2

order_products = [product_1, product_2]
print(order_products)
# Out:
# [('Laptop', 1200), ('Mouse', 25)]

# %% [markdown]
# Agregar un producto

# %%
# TODO: agrega product_3 a order_products
order_products.append(product_3)
print(order_products)
# Out:
# [('Laptop', 1200), ('Mouse', 25), ('Keyboard', 80)]

# %% [markdown]
# Quitar un producto

# %%
# TODO: elimina product_2 de order_products
order_products.remove(product_2)
print(order_products)
# Out:
# [('Laptop', 1200), ('Keyboard', 80)]

# %% [markdown]
# ## Parte 3 : Información del pedido (Diccionario)
#
# --> Usamos un diccionario para acceder a los datos usando claves, no posiciones.

# %% [markdown]
# **Instrucción**
#
# Completa el diccionario con la siguiente información:
# La primera clienta se llama Anna Lopez.
# Los productos que compró están ordenados en una lista específica (creada previamente).
# Su pedido está 'pending' por ahora.

# %%
# TODO: completa el diccionario

order = {
    "customer_name": "Anna Lopez",
    "products": order_products,
    "status": "pending"
}

print(order)
# Out:
# {'customer_name': 'Anna Lopez', 'products': [('Laptop', 1200), ('Keyboard', 80)], 'status': 'pending'}

# %% [markdown]
# ## Parte 4 : Acceder a los datos

# %% [markdown]
# Tareas

# %%
# TODO: imprime el nombre del cliente
print(order["customer_name"])

# TODO: imprime el estado del pedido
print(order["status"])

# TODO: imprime el nombre del primer producto
print(order["products"][0][0])
# Out:
# [('Laptop', 1200), ('Keyboard', 80)]

# %% [markdown]
# ## Parte 5 : Modificar datos

# %% [markdown]
# Cambiar el estado del pedido

# %%
# TODO: cambia el estado del pedido de Anna Lopez a "shipped"
order["status"] = "shipped"
print(order)
# Out:
# {'customer_name': 'Anna Lopez', 'products': [('Laptop', 1200), ('Keyboard', 80)], 'status': 'shipped'}

# %% [markdown]
# Intentar modificar una tupla (a propósito)

# %%
# TODO: intenta cambiar el precio de product_1
product_1[1] = 1500
# ¿Qué sucede?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3303947813.py in <cell line: 0>()
#       1 # TODO: intenta cambiar el precio de product_1
# ----> 2 product_1[1] = 1500
#       3 # ¿Qué sucede?
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Parte 6 : Calcular el precio total

# %% [markdown]
# **Instrucción**
#
# Recorre la lista de productos y calcula el total del pedido.

# %%
total_price = 0

# TODO: recorre order["products"]

products = order["products"]

# TODO: suma el precio de cada producto a total_price

total_price = products[0][1] + products[1][1]

print("Precio total:", total_price)
# Out:
# Precio total: 1280
